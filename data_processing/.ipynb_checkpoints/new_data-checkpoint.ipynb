# %%
#pip install wwo-hist
# Out:
# ...
#   Stored in directory: /home/dmitry/.cache/pip/wheels/c5/0e/16/329d9233f3b0b7e5fe81b09c5519a193727999c6ae77577ca9
# Successfully built wwo-hist
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#from wwo_hist import retrieve_hist_data

# %%
#import os
#os.chdir(".")

# %%
'''frequency = 12
start_date = '1-MAY-2010'
end_date = '1-MAY-2020'
api_key = '17c1ea07d59e414eafb80816200105'
location_list = ['moscow']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for moscow
#
#
# Currently retrieving data for moscow: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.473677
# Currently retrieving data for moscow: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.566395
# Currently retrieving data for moscow: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.685792
# Currently retrieving data for moscow: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.031421
# Currently retrieving data for moscow: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.019805
# Currently retrieving data for moscow: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.061428
# Currently retrieving data for moscow: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.107126
# Currently retrieving data for moscow: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.159207
# ...

# %%
#import pandas as pd
#data = pd.read_csv('moscow.csv')

# %%
#data.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour',
#        'uvIndex', 'uvIndex.1', 'moon_illumination', 'moonrise', 'moonset',
#        'sunrise', 'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC',
#        'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity', 'precipMM',
#        'pressure', 'tempC', 'visibility', 'winddirDegree', 'windspeedKmph'],
#       dtype='object')

# %%
#data.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2010-05-01 00:00:00        20         8           0.0     12.6        3
# 1  2010-05-01 12:00:00        20         8           0.0     12.6        3
# 2  2010-05-02 00:00:00        20        12           0.0     12.6        4
# 3  2010-05-02 12:00:00        20        12           0.0     12.6        4
# 4  2010-05-03 00:00:00        21        12           0.0     12.6        3
#
#    uvIndex.1  moon_illumination     moonrise   moonset  ... WindChillC  \
# 0          1                 78  No moonrise  05:46 AM  ...          6
# 1          4                 78  No moonrise  05:46 AM  ...         20
# 2          1                 71     12:16 AM  06:41 AM  ...         13
# 3          5                 71     12:16 AM  06:41 AM  ...         21
# 4          1                 64     12:58 AM  07:49 AM  ...         13
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
#pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import csv
import pandas as pd

response = requests.get("http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-04-01&enddate=2009-05-01&key=17c1ea07d59e414eafb80816200105&format=csv")

# %%
#data from 2009-04-01 to 2020-02-
CSV_URL1 = 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date='
begin1 = '2009'
begin2 = '-'
begin3 = '4'
CSV_URL2 = '-01&enddate='
end1 = '2009'
end2 = '-'
end3 = '5'
CSV_URL3 = '-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12'
flag = 0


while end1 + end2 + end3 != '2020-4':
    CSV_URL = CSV_URL1
    CSV_URL += begin1 + begin2 + begin3 + CSV_URL2 + end1 + end2 + end3 + CSV_URL3
    print(CSV_URL)
    
    with requests.Session() as s:
        download = s.get(CSV_URL)

        decoded_content = download.content.decode('utf-8')

        cr = csv.reader(decoded_content.splitlines(), delimiter=',')
        my_list = list(cr)
        
    data = my_list
    
    maximum = 0
    counter = collections.defaultdict(int)
    for row in data:
        counter[row[0]] += 1
        if counter[row[0]] > maximum:
            maximum = counter[row[0]]
    
    if flag == 0:
        writer = csv.writer(open("Weather_data.csv", 'w'))
        flag += 1
    else:
        writer = csv.writer(open("Weather_data.csv", 'a'))
        
    for row in data:
        if counter[row[0]] >= maximum:
            writer.writerow(row)
    
    
    begin3 = str(int(begin3) + 1)
    end3 = str(int(end3) + 1)
    if begin3 == '13':
        begin3 = '1'
        begin1 = str(int(begin1) + 1)
    if end3 == '13':
        end3 = '1'
        end1 = str(int(end1) + 1)
# Out:
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-4-01&enddate=2009-5-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-5-01&enddate=2009-6-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-6-01&enddate=2009-7-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-7-01&enddate=2009-8-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-8-01&enddate=2009-9-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2009-9-01&enddate=2009-10-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# ...

# %%
#data from 2020-02-01 to 2020-04-18
CSV_URL1 = 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date='
begin1 = '2020'
begin2 = '-'
begin3 = '2'
CSV_URL2 = '-01&enddate='
end1 = '2020'
end2 = '-'
end3 = '3'
CSV_URL3 = '-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12'
flag = 0


while end1 + end2 + end3 != '2020-6':
    CSV_URL = CSV_URL1
    CSV_URL += begin1 + begin2 + begin3 + CSV_URL2 + end1 + end2 + end3 + CSV_URL3
    print(CSV_URL)
    
    with requests.Session() as s:
        download = s.get(CSV_URL)

        decoded_content = download.content.decode('utf-8')

        cr = csv.reader(decoded_content.splitlines(), delimiter=',')
        my_list = list(cr)
        
    data = my_list
    
    maximum = 0
    counter = collections.defaultdict(int)
    for row in data:
        counter[row[0]] += 1
        if counter[row[0]] > maximum:
            maximum = counter[row[0]]
    
    if flag == 0:
        writer = csv.writer(open("Weather_data.csv", 'w'))
        flag += 1
    else:
        writer = csv.writer(open("Weather_data.csv", 'a'))
        
    for row in data:
        if counter[row[0]] >= maximum:
            writer.writerow(row)
    
    
    begin3 = str(int(begin3) + 1)
    end3 = str(int(end3) + 1)
    if begin3 == '13':
        begin3 = '1'
        begin1 = str(int(begin1) + 1)
    if end3 == '13':
        end3 = '1'
        end1 = str(int(end1) + 1)
# Out:
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2020-2-01&enddate=2020-3-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2020-3-01&enddate=2020-4-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date=2020-4-01&enddate=2020-5-01&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12

# %%
#response.text.to_csv('data_weather.csv')
'''
import csv
import requests

CSV_URL1 = 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q=Moscow&date='
begin1 = '2009'
begin2 = '-'
begin3 = '6'
begin4 = '-01'
CSV_URL2 = '&enddate='
end1 = '2009'
end2 = '-'
end3 = '7'
end4 = '-01'
CSV_URL3 = '&key=17c1ea07d59e414eafb80816200105&format=csv&tp=12'

CSV_URL = CSV_URL1
CSV_URL += begin1 + begin2 + begin3 + CSV_URL2 + end1 + end2 + end3 + CSV_URL3

with requests.Session() as s:
    download = s.get(CSV_URL)

    decoded_content = download.content.decode('utf-8')

    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)

# %%
#my_list[0]
#data = pd.read_csv(decoded_content.splitlines(), delimiter=',')

# %%
'''
import csv

data = my_list

import collections
counter = collections.defaultdict(int)
maximum = 0
for row in data:
    counter[row[0]] += 1
    if counter[row[0]] > maximum:
        maximum = counter[row[0]]


writer = csv.writer(open("weather_data.csv", 'w'))
for row in data:
    if counter[row[0]] >= maximum:
        writer.writerow(row)

# %%
'''
len(data)
# Out:
# 104

# %%
cols = ['date',
 'time',
 'tempC',
 'tempF',
 'windspeedMiles',
 'windspeedKmph',
 'winddirdegree',
 'winddir16point',
 'weatherCode',
 'weatherIconUrl',
 'weatherDesc',
 'precipMM',
 'precipInches',
 'humidity',
 'visibilityKm',
 'visibilityMiles',
 'pressureMB',
 'pressureInches',
 'cloudcover',
 'HeatIndexC',
 'HeatIndexF',
 'DewPointC',
 'DewPointF',
 'WindChillC',
 'WindChillF',
 'WindGustMiles',
 'WindGustKmph',
 'FeelsLikeC',
 'FeelsLikeF']
data_w = pd.read_csv('Weather_data.csv', names=cols)

# %%
data_w = data_w.dropna()

# %%
data_w = pd.DataFrame.drop_duplicates(data_w)

# %%
data_w.to_csv('final_data2.csv', index=False)

# %%
data1 = pd.read_csv('final_data.csv')
data2 = pd.read_csv('final_data2.csv')

# %%
result = pd.concat([data1, data2], ignore_index=True)

# %%
result = pd.DataFrame.drop_duplicates(result)

# %%
result.to_csv('worldweatheronline.com/result_data.csv', index=False)
