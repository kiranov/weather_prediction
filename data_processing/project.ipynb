# %%
import numpy as np

# %% [markdown]
# # Рассмотрим простейшую модель

# %% [markdown]
# Пусть имеется $n$ состоянии и вектор распределения вероятностей в начальный момент времени: $p^0 = (p_1^0, ... , p_n^0)$. То есть в начальный момент времени мы находимся в состоянии один с вероятностью $p_1^0$, в состоянии два с вероятностью  $p_2^0$ и т. д.
#
# Из каждого состояния можно перейти в другое с некоторой вероятностью. Переходы определяются переходной матрицей $T^{n \times n}$.
#
# Чтобы определить распределение вероятностей в момент времени $1$, нужно умножить $p^0$ на $T$. Эту же операцию можно повторить произвольное количество раз и, таким образом, определить распределение вероятностей в произвольный момент времени $m$.
#
# $p^m = p^0 \times T^m$

# %% [markdown]
# пусть имеется три состояния: солнечно, пасмурно, идет дождь и про сегодняшний день мы знаем, что светит солнце. Тогда $p^0 = (1, 0, 0)$
#
#
# Определим переходную матрицу:
#
# $\begin{equation*}
# T =
# \begin{pmatrix}
# 0.5 & 0.3 & 0.2\\
# 0.25 & 0.5 & 0.25\\
# 0.2 & 0.4 & 0.4
# \end{pmatrix}
# \end{equation*}$
#
# Зададимся вопросом определения погоды на завтра, послезавтра, 10 день, 100 и 1000.

# %%
p0 = np.array([0.8, 0.2, 0])
p01 = np.array([1, 0, 0])
T = np.array([[0.5, 0.3, 0.2], [0.25, 0.5, 0.25], [0.2, 0.4, 0.4]])

# %%
print(p0@T, "- завтра")
print(p0@np.linalg.matrix_power(T, 2), '- послезавтра')
print(p0@np.linalg.matrix_power(T, 10), '- 10 день')
print(p0@np.linalg.matrix_power(T, 100), '- 100 день')
print(p0@np.linalg.matrix_power(T, 1000), '- 1000 день')
# Out:
# [0.45 0.34 0.21] - завтра
# [0.352 0.389 0.259] - послезавтра
# [0.31496171 0.40944819 0.2755901 ] - 10 день
# [0.31496063 0.40944882 0.27559055] - 100 день
# [0.31496063 0.40944882 0.27559055] - 1000 день

# %%
print(p01@T, "- завтра")
print(p01@np.linalg.matrix_power(T, 2), '- послезавтра')
print(p01@np.linalg.matrix_power(T, 10), '- 10 день')
print(p01@np.linalg.matrix_power(T, 100), '- 100 день')
print(p01@np.linalg.matrix_power(T, 1000), '- 1000 день')
# Out:
# [0.5 0.3 0.2] - завтра
# [0.365 0.38  0.255] - послезавтра
# [0.31496207 0.40944797 0.27558995] - 10 день
# [0.31496063 0.40944882 0.27559055] - 100 день
# [0.31496063 0.40944882 0.27559055] - 1000 день

# %% [markdown]
# как видно, при прогнозе на длительное время распределения совпадают, откуда логично предположить, что оно определяется переходной матрицей, а не начальным распределением

# %% [markdown]
# # Идея для температуры

# %% [markdown]
# будем рассматривать следующий вектор: $t = (t_{<-5}, t_{[-5;-2]}, t_{[-2;2]}, t_{[2;5]}, t_{>5})$
#
# $t_{<-5}$ - температура уменьшится более чем на 5 градусов,
#
# $t_{[-5;-2]}$ - температура уменьшится на 2-5 градусов,
#
# $t_{[-2;2]}$ - температура будет меняться в пределах от -2 до 2 градусов,
#
# $t_{[2;5]}$ - температура увеличиться на 2-5 градусов ,
#
# $t_{>5}$ - температура увеличится более чем на 5 градусов

# %% [markdown]
# $\begin{equation*}
# T =
# \begin{pmatrix}
# 0.05 & 0.15 & 0.4 & 0.3 & 0.1\\
# 0.05 & 0.2 & 0.3 & 0.4 & 0.05\\
# 0.1 & 0.2 & 0.4 & 0.2 & 0.1\\
# 0.05 & 0.4 & 0.3 & 0.2 & 0.05\\
# 0.1 & 0.3 & 0.4 & 0.15 & 0.05
# \end{pmatrix}
# \end{equation*}$

# %% [markdown]
# берем погоду за 2 дня, высчитываем вектор $t_0$
#
# р/м два $t_0$:
#
# $t_{01} = (0, 0, 1, 0, 0)$
#
# $t_{02} = (0.05, 0.2, 0.5, 0.2, 0.05)$
#
# Определим погоду на завтра, послезавтра, 10, 100 и 100 дней

# %%
t01 = np.array([0, 0, 1, 0, 0])
t02 = np.array([0.05, 0.2, 0.5, 0.2, 0.05])
T_t = np.array([[0.05, 0.15, 0.4, 0.3, 0.1], 
                [0.05, 0.2, 0.3, 0.4, 0.05],
                [0.1, 0.2, 0.4, 0.2, 0.1],
                [0.05, 0.4, 0.3, 0.2, 0.05],
                [0.1, 0.3, 0.4, 0.15, 0.05]])

# %%
print("t01")
print(t01@T_t, "- завтра")
print(t01@np.linalg.matrix_power(T_t, 2), '- послезавтра')
print(t01@np.linalg.matrix_power(T_t, 3), '- через 2 дня')
print(t01@np.linalg.matrix_power(T_t, 4), '- через 3 дня')
print(t01@np.linalg.matrix_power(T_t, 5), '- через 4 дня')
print(t01@np.linalg.matrix_power(T_t, 10), '- 10 день')
print(t01@np.linalg.matrix_power(T_t, 100), '- 100 день')
print(t01@np.linalg.matrix_power(T_t, 1000), '- 1000 день')
# Out:
# t01
# [0.1 0.2 0.4 0.2 0.1] - завтра
# [0.075 0.245 0.36  0.245 0.075] - послезавтра
# [0.07175 0.25275 0.351   0.25275 0.07175] - через 2 дня
# [0.0711375 0.2541375 0.34945   0.2541375 0.0711375] - через 3 дня
# [0.07102938 0.25438438 0.3491725  0.25438438 0.07102938] - через 4 дня
# [0.07100592 0.25443786 0.34911244 0.25443786 0.07100592] - 10 день
# [0.07100592 0.25443787 0.34911243 0.25443787 0.07100592] - 100 день
# [0.07100592 0.25443787 0.34911243 0.25443787 0.07100592] - 1000 день

# %%
print("t02")
print(t02@T_t, "- завтра")
print(t02@np.linalg.matrix_power(T_t, 2), '- послезавтра')
print(t02@np.linalg.matrix_power(T_t, 3), '- через 2 дня')
print(t02@np.linalg.matrix_power(T_t, 4), '- через 3 дня')
print(t02@np.linalg.matrix_power(T_t, 5), '- через 4 дня')
print(t02@np.linalg.matrix_power(T_t, 10), '- 10 день')
print(t02@np.linalg.matrix_power(T_t, 100), '- 100 день')
print(t02@np.linalg.matrix_power(T_t, 1000), '- 1000 день')
# Out:
# t02
# [0.0775 0.2425 0.36   0.2425 0.0775] - завтра
# [0.071875 0.252375 0.3515   0.252375 0.071875] - послезавтра
# [0.07116875 0.25406875 0.349525   0.25406875 0.07116875] - через 2 дня
# [0.07103469 0.25437219 0.34918625 0.25437219 0.07103469] - через 3 дня
# [0.07101105 0.25442617 0.34912556 0.25442617 0.07101105] - через 4 дня
# [0.07100592 0.25443787 0.34911243 0.25443787 0.07100592] - 10 день
# [0.07100592 0.25443787 0.34911243 0.25443787 0.07100592] - 100 день
# [0.07100592 0.25443787 0.34911243 0.25443787 0.07100592] - 1000 день

# %% [markdown]
# # Мысли:
#     1)хорошо бы попробовать собрать статистику по погоде за несколько  лет и составить переходные матрицы для каждого месяца(и по общему прогнозу и по температуре)
#         данные скачал, необходимо разбить
#     2)для пострения обучающей выборки поступим так:
#       в первом приближении разобьём год по месяцам, в пределах одного месяца поступим следующим образом: рассмо-трим все солнечные дни, посмотрим следующие за ними дни, пусть соленчых дней 20, а следующих за ним солнечных дней 15, пасмурных 3, дождливых 2, тогда
# $T_0 = (\frac{15}{20}, \frac{3}{20}, \frac{2}{20})$ - первая строка матрицы переходов

# %%
import pandas as pd

# %%
data = pd.read_csv('rp5.ru/погода.csv')

# %%
data.head(5)
# Out:
#   Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)    T     Po  \
# 0                                   25.04.2020 12:00          7.7  730.7
# 1                                   25.04.2020 09:00          5.2  730.4
# 2                                   25.04.2020 06:00          3.4  730.1
# 3                                   25.04.2020 03:00          3.7  730.1
# 4                                   25.04.2020 00:00          5.0  730.6
#
#        P  Pa     U                                 DD   Ff  ff10  ff3  ...  \
# 0  747.5 NaN  54.0             Ветер, дующий с запада  4.0   NaN  NaN  ...
# 1  747.4 NaN  86.0             Ветер, дующий с запада  5.0   NaN  NaN  ...
# 2  747.2 NaN  95.0             Ветер, дующий с запада  3.0   NaN  NaN  ...
# 3  747.1 NaN  93.0             Ветер, дующий с запада  4.0   NaN  NaN  ...
# 4  747.6 NaN  88.0  Ветер, дующий с западо-юго-запада  4.0   NaN  NaN  ...
#
#                                                   Cm  \
# 0  Высококучевые, образовавшиеся из кучевых (или ...
# 1  Высококучевые просвечивающие, полосами, либо о...
# 2  Высококучевые просвечивающие, расположенные на...
# 3  Высококучевые просвечивающие, расположенные на...
# 4  Высококучевые просвечивающие, расположенные на...
#
#                                                   Ch  VV   Td            RRR  \
# 0  Перистых, перисто-кучевых или перисто-слоистых...  10 -1.1            NaN
# 1  Перистых, перисто-кучевых или перисто-слоистых...  10  3.1  Следы осадков
# 2  Перистых, перисто-кучевых или перисто-слоистых...  10  2.7            NaN
# 3  Перистых, перисто-кучевых или перисто-слоистых...  10  2.6            NaN
# 4  Перистых, перисто-кучевых или перисто-слоистых...  10  3.2            NaN
#
#      tR   E  Tg  E' sss
# 0   NaN NaN NaN NaN NaN
# 1  12.0 NaN NaN NaN NaN
# 2   NaN NaN NaN NaN NaN
# 3   NaN NaN NaN NaN NaN
# 4   NaN NaN NaN NaN NaN
#
# [5 rows x 29 columns]

# %%
data['WW'].unique()
# Out:
# array([' ', 'Состояние неба в общем не изменилось. ',
#        'Ливневый(ые) дождь(и). ',
#        'Ливневый(ые) дождь(и) слабый(ые) в срок наблюдения или за последний час. ',
#        'Облака в целом рассеиваются или становятся менее развитыми. ',
#        'Пыль или песок, поднятые ветром на или вблизи станции в срок наблюдения, но нет хорошо развитого пыльного или песчаного вихря (вихрей), и никакой пыльной или песчаной бури не видно; или, в случае сообщения с судна или с береговой станции, брызги, переносимые ветром на станции. ',
#        'Ливневый снег слабый в срок наблюдения или за последний час. ',
#        'Видимость ухудшена дымом, например: от степных или лесных пожаров, промышленных предприятий или вулканическим пеплом. ',
#        'Дымка. ',
#        'Морось незамерзающая непрерывная слабая в срок наблюдения. ',
#        'Дождь или морось со снегом слабые. ',
#        'Снег непрерывный слабый в срок наблюдения. ',
#        'Ливневый снег или ливневый дождь и снег. ',
#        'Дождь незамерзающий непрерывный слабый в срок наблюдения. ',
#        'Дождь (незамерзающий) неливневый. ',
#        'Пыль, взвешенная в воздухе на обширном пространстве, но не поднятая ветром на или вблизи станции в срок наблюдения. ',
#        'Снег неливневый. ',
#        'Снег непрерывный умеренный в срок наблюдения. ', 'Мгла. ',
#        'Ливневый снег умеренный или сильный в срок наблюдения или за последний час. ',
#        'Морось (незамерзающая) или снежные зерна неливневые. ',
#        'Туман или ледяной туман, неба не видно, без заметного изменения интенсивности в течение последнего часа. ',
#        'Туман или ледяной туман, неба не видно, начался или усилился в течение последнего часа. ',
#        'Туман или ледяной туман. ',
#        'Снег непрерывный сильный в срок наблюдения. ',
#        'Туман или ледяной туман, небо видно, без заметного изменения интенсивности в течение последнего часа. ',
#        'Алмазная пыль (с туманом или без него). ',
#        'Снег с перерывами умеренный в срок наблюдения. ',
#        'Дождь со снегом или ледяная крупа неливневые. ',
#        'Ливневый(ые) дождь(и) со снегом слабый(ые) в срок наблюдения или за последний час. ',
#        'Туман или ледяной туман, небо видно, начался или усилился в течение последнего часа. ',
#        'Морось замерзающая слабая. ',
#        'Снег с перерывами слабый в срок наблюдения. ',
#        'Дождь замерзающий слабый. ',
#        'Туман или ледяной туман, неба не видно, ослабел за последний час. ',
#        'Дождь незамерзающий с перерывами умеренный в срок наблюдения. ',
#        'Облака в целом образовывались или развивались. ',
#        'Дождь незамерзающий с перерывами слабый в срок наблюдения. ',
#        'Ливневый(ые) дождь(и) умеренный(ые) или сильный(ые) в срок наблюдения или за последний час. ',
#        'Ливневый град, или дождь и град. ',
#        'Туман или ледяной туман, небо видно, ослабел за последний час. ',
#        'Слабый дождь в срок наблюдения. Гроза в течение последнего часа, но не в срок наблюдения. ',
#        'Гроза (с осадками или без них). ',
#        'Гроза, но без осадков, в срок наблюдения. ',
#        'Гроза слабая или умеренная без града, но с дождем и/или снегом в срок наблюдения. ',
#        'Слабый или умеренный поземок в целом низкий (ниже уровня глаз наблюдателя). ',
#        'Замерзающая морось или замерзающий дождь неливневые. ',
#        'Туман с отложением изморози, небо видно. ',
#        'Клочья приземного или ледяного тумана на станции, на море или на суше, высотой не более 2 м над сушей или не более 10 м над морем. ',
#        'Гроза слабая или умеренная с градом в срок наблюдения. ',
#        'Ливневая снежная крупа или небольшой град с дождем или без него, или дождь со снегом слабые в срок наблюдения или за последний час. ',
#        'Ливневый(ые) дождь(и) со снегом умеренный(ые) или сильный(ые) в срок наблюдения или за последний час. ',
#        'Дождь замерзающий умеренный или сильный. ',
#        'Снежные зерна (с туманом или без него). ',
#        'Морось незамерзающая с перерывами слабая в срок наблюдения. ',
#        'Ледяная крупа. ', 'Видна молния, грома не слышно. ',
#        'Морось незамерзающая непрерывная умеренная в срок наблюдения. ',
#        'Ливневая снежная крупа или небольшой град с дождем или без него, или дождь со снегом умеренные или сильные в срок наблюдения или за последний час. ',
#        'Дождь незамерзающий непрерывный умеренный в срок наблюдения. ',
#        'Более или менее сплошной слой приземного или ледяного тумана на станции, на море или на суше, высотой не более 2 м над сушей или не более 10 м над морем. '],
#       dtype=object)

# %%
data['W1'].unique()
# Out:
# array([nan, 'Ливень (ливни).',
#        'Облака покрывали половину неба или менее в течение всего соответствующего периода.',
#        'Облака покрывали более половины неба в течение всего соответствующего периода.',
#        'Дождь со снегом или другими видами твердых осадков', 'Дождь.',
#        'Облака покрывали более половины неба в течение одной части соответствующего периода и половину или менее в течение другой части периода.',
#        'Снег и/или другие виды твердых осадков',
#        'Туман или ледяной туман или сильная мгла.', 'Морось.',
#        'Гроза (грозы) с осадками или без них.', 'Метель', 'Буря'],
#       dtype=object)

# %% [markdown]
# для простоты будем брать погоду в 12 часов дня: температура - T, облачность - N(%), и осадки W1

# %%
data[['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)', 'T', 'N', 'WW']].head(15)
# Out:
#    Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)    T  \
# 0                                    25.04.2020 12:00          7.7
# 1                                    25.04.2020 09:00          5.2
# 2                                    25.04.2020 06:00          3.4
# 3                                    25.04.2020 03:00          3.7
# 4                                    25.04.2020 00:00          5.0
# 5                                    24.04.2020 21:00          5.5
# 6                                    24.04.2020 18:00          6.3
# 7                                    24.04.2020 15:00          6.8
# 8                                    24.04.2020 12:00          8.1
# 9                                    24.04.2020 09:00          4.1
# 10                                   24.04.2020 06:00         -1.0
# 11                                   24.04.2020 03:00         -2.1
# 12                                   24.04.2020 00:00          1.2
# 13                                   23.04.2020 21:00          4.3
# 14                                   23.04.2020 18:00          9.0
#
#                             N  \
# 0                   70 – 80%.
# 1                   70 – 80%.
# 2                   70 – 80%.
# 3   90  или более, но не 100%
# 4   90  или более, но не 100%
# 5                   70 – 80%.
# 6   90  или более, но не 100%
# 7                       100%.
# 8                       100%.
# 9                        50%.
# 10                    20–30%.
# 11                    20–30%.
# 12                    20–30%.
# 13                       60%.
# 14                       60%.
#
#                                                    WW
# 0
# 1              Состояние неба в общем не изменилось.
# 2              Состояние неба в общем не изменилось.
# 3                             Ливневый(ые) дождь(и).
# 4
# 5              Состояние неба в общем не изменилось.
# 6              Состояние неба в общем не изменилось.
# 7   Ливневый(ые) дождь(и) слабый(ые) в срок наблюд...
# 8
# 9
# 10
# 11
# 12
# 13
# 14

# %%
import time

struct_time = time.strptime(data['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)'][0],
                                "%d.%m.%Y %H:%M")

# %%
import datetime

print(struct_time)
print(struct_time.tm_hour)
# Out:
# time.struct_time(tm_year=2020, tm_mon=4, tm_mday=25, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=116, tm_isdst=-1)
# 12

# %%
table0 = data[['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)', 'T', 'W1', 'N']]

# %%
#table1['hour'] = time.strptime(data['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)']).tm_hour
table0['hour'] = [time.strptime(n, "%d.%m.%Y %H:%M").tm_hour for n in table0['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)']]
table0['day'] = [time.strptime(n, "%d.%m.%Y %H:%M").tm_mday for n in table0['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)']]
table0['month'] = [time.strptime(n, "%d.%m.%Y %H:%M").tm_mon for n in table0['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)']]
table0['year'] = [time.strptime(n, "%d.%m.%Y %H:%M").tm_year for n in table0['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)']]
# Out:
# /home/dmitry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/dmitry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/dmitry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/dmitry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
table0['status'] = [1 if n >= 12 else 0 for n in table0['hour']]
#prices = [i if i > 0 else 0 for i in original_prices]
# Out:
# /home/dmitry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
table0
# Out:
#       Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)     T  \
# 0                                       25.04.2020 12:00           7.7
# 1                                       25.04.2020 09:00           5.2
# 2                                       25.04.2020 06:00           3.4
# 3                                       25.04.2020 03:00           3.7
# 4                                       25.04.2020 00:00           5.0
# 5                                       24.04.2020 21:00           5.5
# 6                                       24.04.2020 18:00           6.3
# 7                                       24.04.2020 15:00           6.8
# 8                                       24.04.2020 12:00           8.1
# 9                                       24.04.2020 09:00           4.1
# 10                                      24.04.2020 06:00          -1.0
# 11                                      24.04.2020 03:00          -2.1
# 12                                      24.04.2020 00:00           1.2
# 13                                      23.04.2020 21:00           4.3
# 14                                      23.04.2020 18:00           9.0
# 15                                      23.04.2020 15:00           9.8
# 16                                      23.04.2020 12:00           8.4
# 17                                      23.04.2020 09:00           5.5
# 18                                      23.04.2020 06:00           1.8
# 19                                      23.04.2020 03:00           2.1
# 20                                      23.04.2020 00:00           3.3
# 21                                      22.04.2020 21:00           4.6
# 22                                      22.04.2020 18:00           6.7
# 23                                      22.04.2020 15:00           6.4
# 24                                      22.04.2020 12:00           4.3
# 25                                      22.04.2020 09:00           5.4
# 26                                      22.04.2020 06:00           4.3
# 27                                      22.04.2020 03:00           5.2
# 28                                      22.04.2020 00:00           5.5
# 29                                      21.04.2020 21:00           6.3
# ...                                                  ...           ...
# 25023                                   04.04.2010 18:00          11.5
# 25024                                   04.04.2010 15:00          12.6
# 25025                                   04.04.2010 12:00          10.2
# 25026                                   04.04.2010 09:00           4.7
# 25027                                   04.04.2010 06:00           0.5
# 25028                                   04.04.2010 03:00           2.9
# 25029                                   04.04.2010 00:00           6.5
# 25030                                   03.04.2010 21:00           9.2
# 25031                                   03.04.2010 18:00          12.0
# 25032                                   03.04.2010 15:00          13.3
# 25033                                   03.04.2010 12:00          10.1
# 25034                                   03.04.2010 09:00           4.6
# 25035                                   03.04.2010 06:00           1.6
# 25036                                   03.04.2010 03:00           2.2
# 25037                                   03.04.2010 00:00           4.2
# 25038                                   02.04.2010 21:00           9.6
# 25039                                   02.04.2010 15:00          13.8
# 25040                                   02.04.2010 12:00          10.4
# 25041                                   02.04.2010 09:00           5.5
# 25042                                   02.04.2010 06:00           3.1
# 25043                                   02.04.2010 03:00           4.3
# 25044                                   02.04.2010 00:00           8.5
# 25045                                   01.04.2010 21:00           9.3
# 25046                                   01.04.2010 18:00          11.2
# 25047                                   01.04.2010 15:00          10.8
# 25048                                   01.04.2010 12:00          10.1
# 25049                                   01.04.2010 09:00           5.6
# 25050                                   01.04.2010 06:00           3.5
# 25051                                   01.04.2010 03:00           4.2
# 25052                                   01.04.2010 00:00           5.6
#
#                                                       W1  \
# 0                                                    NaN
# 1                                        Ливень (ливни).
# 2                                        Ливень (ливни).
# 3                                        Ливень (ливни).
# 4                                                    NaN
# 5                                        Ливень (ливни).
# 6                                        Ливень (ливни).
# 7                                        Ливень (ливни).
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20     Облака покрывали половину неба или менее в теч...
# 21     Облака покрывали половину неба или менее в теч...
# 22     Облака покрывали более половины неба в течение...
# 23                                       Ливень (ливни).
# 24                                       Ливень (ливни).
# 25     Облака покрывали более половины неба в течение...
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 25023                                                NaN
# 25024                                                NaN
# 25025                                                NaN
# 25026                                                NaN
# 25027                                                NaN
# 25028                                                NaN
# 25029                                                NaN
# 25030                                                NaN
# 25031                                                NaN
# 25032                                                NaN
# 25033                                                NaN
# 25034                                                NaN
# 25035                                                NaN
# 25036                                                NaN
# 25037                                                NaN
# 25038                                                NaN
# 25039                                                NaN
# 25040                                                NaN
# 25041                                                NaN
# 25042                                                NaN
# 25043                                                NaN
# 25044                                                NaN
# 25045                                                NaN
# 25046                                                NaN
# 25047                                                NaN
# 25048                                                NaN
# 25049                                                NaN
# 25050  Облака покрывали более половины неба в течение...
# 25051  Облака покрывали более половины неба в течение...
# 25052                                                NaN
#
#                                N  hour  day  month  year  status
# 0                      70 – 80%.    12   25      4  2020       1
# 1                      70 – 80%.     9   25      4  2020       0
# 2                      70 – 80%.     6   25      4  2020       0
# 3      90  или более, но не 100%     3   25      4  2020       0
# 4      90  или более, но не 100%     0   25      4  2020       0
# 5                      70 – 80%.    21   24      4  2020       1
# 6      90  или более, но не 100%    18   24      4  2020       1
# 7                          100%.    15   24      4  2020       1
# 8                          100%.    12   24      4  2020       1
# 9                           50%.     9   24      4  2020       0
# 10                       20–30%.     6   24      4  2020       0
# 11                       20–30%.     3   24      4  2020       0
# 12                       20–30%.     0   24      4  2020       0
# 13                          60%.    21   23      4  2020       1
# 14                          60%.    18   23      4  2020       1
# 15                          60%.    15   23      4  2020       1
# 16                          60%.    12   23      4  2020       1
# 17                          60%.     9   23      4  2020       0
# 18                          60%.     6   23      4  2020       0
# 19                          50%.     3   23      4  2020       0
# 20                       20–30%.     0   23      4  2020       0
# 21                       20–30%.    21   22      4  2020       1
# 22                          40%.    18   22      4  2020       1
# 23                          60%.    15   22      4  2020       1
# 24                          60%.    12   22      4  2020       1
# 25     90  или более, но не 100%     9   22      4  2020       0
# 26                          60%.     6   22      4  2020       0
# 27     90  или более, но не 100%     3   22      4  2020       0
# 28     90  или более, но не 100%     0   22      4  2020       0
# 29     90  или более, но не 100%    21   21      4  2020       1
# ...                          ...   ...  ...    ...   ...     ...
# 25023  90  или более, но не 100%    18    4      4  2010       1
# 25024  90  или более, но не 100%    15    4      4  2010       1
# 25025                  70 – 80%.    12    4      4  2010       1
# 25026                       50%.     9    4      4  2010       0
# 25027                  70 – 80%.     6    4      4  2010       0
# 25028                    20–30%.     3    4      4  2010       0
# 25029                       50%.     0    4      4  2010       0
# 25030                       50%.    21    3      4  2010       1
# 25031                       50%.    18    3      4  2010       1
# 25032               Облаков нет.    15    3      4  2010       1
# 25033    10%  или менее, но не 0    12    3      4  2010       1
# 25034                    20–30%.     9    3      4  2010       0
# 25035                  70 – 80%.     6    3      4  2010       0
# 25036                       50%.     3    3      4  2010       0
# 25037                       40%.     0    3      4  2010       0
# 25038                       40%.    21    2      4  2010       1
# 25039                  70 – 80%.    15    2      4  2010       1
# 25040                       60%.    12    2      4  2010       1
# 25041  90  или более, но не 100%     9    2      4  2010       0
# 25042  90  или более, но не 100%     6    2      4  2010       0
# 25043                  70 – 80%.     3    2      4  2010       0
# 25044  90  или более, но не 100%     0    2      4  2010       0
# 25045  90  или более, но не 100%    21    1      4  2010       1
# 25046  90  или более, но не 100%    18    1      4  2010       1
# 25047  90  или более, но не 100%    15    1      4  2010       1
# 25048  90  или более, но не 100%    12    1      4  2010       1
# 25049                  70 – 80%.     9    1      4  2010       0
# 25050  90  или более, но не 100%     6    1      4  2010       0
# 25051  90  или более, но не 100%     3    1      4  2010       0
# 25052  90  или более, но не 100%     0    1      4  2010       0
#
# [25053 rows x 9 columns]

# %%
table0.drop(['Местное время в Шереметьево / им. А. С. Пушкина (аэропорт)'], axis='columns', inplace=True)
# Out:
# /home/dmitry/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#table = table1.loc[(table1['hour'] == 15)]

# %%
#table4 = table1.loc[(table1['month'] == 4) & (table1['hour'] == 15)]
table0
# Out:
#           T                                                 W1  \
# 0       7.7                                                NaN
# 1       5.2                                    Ливень (ливни).
# 2       3.4                                    Ливень (ливни).
# 3       3.7                                    Ливень (ливни).
# 4       5.0                                                NaN
# 5       5.5                                    Ливень (ливни).
# 6       6.3                                    Ливень (ливни).
# 7       6.8                                    Ливень (ливни).
# 8       8.1                                                NaN
# 9       4.1                                                NaN
# 10     -1.0                                                NaN
# 11     -2.1                                                NaN
# 12      1.2                                                NaN
# 13      4.3                                                NaN
# 14      9.0                                                NaN
# 15      9.8                                                NaN
# 16      8.4                                                NaN
# 17      5.5                                                NaN
# 18      1.8                                                NaN
# 19      2.1                                                NaN
# 20      3.3  Облака покрывали половину неба или менее в теч...
# 21      4.6  Облака покрывали половину неба или менее в теч...
# 22      6.7  Облака покрывали более половины неба в течение...
# 23      6.4                                    Ливень (ливни).
# 24      4.3                                    Ливень (ливни).
# 25      5.4  Облака покрывали более половины неба в течение...
# 26      4.3                                                NaN
# 27      5.2                                                NaN
# 28      5.5                                                NaN
# 29      6.3                                                NaN
# ...     ...                                                ...
# 25023  11.5                                                NaN
# 25024  12.6                                                NaN
# 25025  10.2                                                NaN
# 25026   4.7                                                NaN
# 25027   0.5                                                NaN
# 25028   2.9                                                NaN
# 25029   6.5                                                NaN
# 25030   9.2                                                NaN
# 25031  12.0                                                NaN
# 25032  13.3                                                NaN
# 25033  10.1                                                NaN
# 25034   4.6                                                NaN
# 25035   1.6                                                NaN
# 25036   2.2                                                NaN
# 25037   4.2                                                NaN
# 25038   9.6                                                NaN
# 25039  13.8                                                NaN
# 25040  10.4                                                NaN
# 25041   5.5                                                NaN
# 25042   3.1                                                NaN
# 25043   4.3                                                NaN
# 25044   8.5                                                NaN
# 25045   9.3                                                NaN
# 25046  11.2                                                NaN
# 25047  10.8                                                NaN
# 25048  10.1                                                NaN
# 25049   5.6                                                NaN
# 25050   3.5  Облака покрывали более половины неба в течение...
# 25051   4.2  Облака покрывали более половины неба в течение...
# 25052   5.6                                                NaN
#
#                                N  hour  day  month  year  status
# 0                      70 – 80%.    12   25      4  2020       1
# 1                      70 – 80%.     9   25      4  2020       0
# 2                      70 – 80%.     6   25      4  2020       0
# 3      90  или более, но не 100%     3   25      4  2020       0
# 4      90  или более, но не 100%     0   25      4  2020       0
# 5                      70 – 80%.    21   24      4  2020       1
# 6      90  или более, но не 100%    18   24      4  2020       1
# 7                          100%.    15   24      4  2020       1
# 8                          100%.    12   24      4  2020       1
# 9                           50%.     9   24      4  2020       0
# 10                       20–30%.     6   24      4  2020       0
# 11                       20–30%.     3   24      4  2020       0
# 12                       20–30%.     0   24      4  2020       0
# 13                          60%.    21   23      4  2020       1
# 14                          60%.    18   23      4  2020       1
# 15                          60%.    15   23      4  2020       1
# 16                          60%.    12   23      4  2020       1
# 17                          60%.     9   23      4  2020       0
# 18                          60%.     6   23      4  2020       0
# 19                          50%.     3   23      4  2020       0
# 20                       20–30%.     0   23      4  2020       0
# 21                       20–30%.    21   22      4  2020       1
# 22                          40%.    18   22      4  2020       1
# 23                          60%.    15   22      4  2020       1
# 24                          60%.    12   22      4  2020       1
# 25     90  или более, но не 100%     9   22      4  2020       0
# 26                          60%.     6   22      4  2020       0
# 27     90  или более, но не 100%     3   22      4  2020       0
# 28     90  или более, но не 100%     0   22      4  2020       0
# 29     90  или более, но не 100%    21   21      4  2020       1
# ...                          ...   ...  ...    ...   ...     ...
# 25023  90  или более, но не 100%    18    4      4  2010       1
# 25024  90  или более, но не 100%    15    4      4  2010       1
# 25025                  70 – 80%.    12    4      4  2010       1
# 25026                       50%.     9    4      4  2010       0
# 25027                  70 – 80%.     6    4      4  2010       0
# 25028                    20–30%.     3    4      4  2010       0
# 25029                       50%.     0    4      4  2010       0
# 25030                       50%.    21    3      4  2010       1
# 25031                       50%.    18    3      4  2010       1
# 25032               Облаков нет.    15    3      4  2010       1
# 25033    10%  или менее, но не 0    12    3      4  2010       1
# 25034                    20–30%.     9    3      4  2010       0
# 25035                  70 – 80%.     6    3      4  2010       0
# 25036                       50%.     3    3      4  2010       0
# 25037                       40%.     0    3      4  2010       0
# 25038                       40%.    21    2      4  2010       1
# 25039                  70 – 80%.    15    2      4  2010       1
# 25040                       60%.    12    2      4  2010       1
# 25041  90  или более, но не 100%     9    2      4  2010       0
# 25042  90  или более, но не 100%     6    2      4  2010       0
# 25043                  70 – 80%.     3    2      4  2010       0
# 25044  90  или более, но не 100%     0    2      4  2010       0
# 25045  90  или более, но не 100%    21    1      4  2010       1
# 25046  90  или более, но не 100%    18    1      4  2010       1
# 25047  90  или более, но не 100%    15    1      4  2010       1
# 25048  90  или более, но не 100%    12    1      4  2010       1
# 25049                  70 – 80%.     9    1      4  2010       0
# 25050  90  или более, но не 100%     6    1      4  2010       0
# 25051  90  или более, но не 100%     3    1      4  2010       0
# 25052  90  или более, но не 100%     0    1      4  2010       0
#
# [25053 rows x 8 columns]

# %%
table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-b9c74558ed37> in <module>
# ----> 1 table
#
# NameError: name 'table' is not defined

# %%
print(table['Nh'].unique())
print(table['W1'].unique())
# Out:
# ['90  или более, но не 100%' '100%.' 'Облаков нет.' '50%.' '60%.' '40%.'
#  '70 – 80%.' '20–30%.' '10%  или менее, но не 0' nan]
# ['Ливень (ливни).' nan
#  'Облака покрывали более половины неба в течение всего соответствующего периода.'
#  'Дождь.' 'Снег и/или другие виды твердых осадков'
#  'Облака покрывали половину неба или менее в течение всего соответствующего периода.'
#  'Туман или ледяной туман или сильная мгла.'
#  'Дождь со снегом или другими видами твердых осадков' 'Морось.'
#  'Гроза (грозы) с осадками или без них.']

# %% [markdown]
# прогноз будем делать исходя из следующего предположения:
#
#    1)при $Nh \in [0, 50)$ и отсутствии дождя - ясная погода
#
#    2)при $Nh \in [50, 100)$ и отсутствии дождя - облачно
#
#    3)при $W1 \neq Nan$ - дождь

# %%
table0 = table0.sort_values(by=['year', 'month', 'day', 'hour'])

# %%
table0
# Out:
#           T                                                 W1  \
# 25052   5.6                                                NaN
# 25051   4.2  Облака покрывали более половины неба в течение...
# 25050   3.5  Облака покрывали более половины неба в течение...
# 25049   5.6                                                NaN
# 25048  10.1                                                NaN
# 25047  10.8                                                NaN
# 25046  11.2                                                NaN
# 25045   9.3                                                NaN
# 25044   8.5                                                NaN
# 25043   4.3                                                NaN
# 25042   3.1                                                NaN
# 25041   5.5                                                NaN
# 25040  10.4                                                NaN
# 25039  13.8                                                NaN
# 25038   9.6                                                NaN
# 25037   4.2                                                NaN
# 25036   2.2                                                NaN
# 25035   1.6                                                NaN
# 25034   4.6                                                NaN
# 25033  10.1                                                NaN
# 25032  13.3                                                NaN
# 25031  12.0                                                NaN
# 25030   9.2                                                NaN
# 25029   6.5                                                NaN
# 25028   2.9                                                NaN
# 25027   0.5                                                NaN
# 25026   4.7                                                NaN
# 25025  10.2                                                NaN
# 25024  12.6                                                NaN
# 25023  11.5                                                NaN
# ...     ...                                                ...
# 29      6.3                                                NaN
# 28      5.5                                                NaN
# 27      5.2                                                NaN
# 26      4.3                                                NaN
# 25      5.4  Облака покрывали более половины неба в течение...
# 24      4.3                                    Ливень (ливни).
# 23      6.4                                    Ливень (ливни).
# 22      6.7  Облака покрывали более половины неба в течение...
# 21      4.6  Облака покрывали половину неба или менее в теч...
# 20      3.3  Облака покрывали половину неба или менее в теч...
# 19      2.1                                                NaN
# 18      1.8                                                NaN
# 17      5.5                                                NaN
# 16      8.4                                                NaN
# 15      9.8                                                NaN
# 14      9.0                                                NaN
# 13      4.3                                                NaN
# 12      1.2                                                NaN
# 11     -2.1                                                NaN
# 10     -1.0                                                NaN
# 9       4.1                                                NaN
# 8       8.1                                                NaN
# 7       6.8                                    Ливень (ливни).
# 6       6.3                                    Ливень (ливни).
# 5       5.5                                    Ливень (ливни).
# 4       5.0                                                NaN
# 3       3.7                                    Ливень (ливни).
# 2       3.4                                    Ливень (ливни).
# 1       5.2                                    Ливень (ливни).
# 0       7.7                                                NaN
#
#                                N  hour  day  month  year  status
# 25052  90  или более, но не 100%     0    1      4  2010       0
# 25051  90  или более, но не 100%     3    1      4  2010       0
# 25050  90  или более, но не 100%     6    1      4  2010       0
# 25049                  70 – 80%.     9    1      4  2010       0
# 25048  90  или более, но не 100%    12    1      4  2010       1
# 25047  90  или более, но не 100%    15    1      4  2010       1
# 25046  90  или более, но не 100%    18    1      4  2010       1
# 25045  90  или более, но не 100%    21    1      4  2010       1
# 25044  90  или более, но не 100%     0    2      4  2010       0
# 25043                  70 – 80%.     3    2      4  2010       0
# 25042  90  или более, но не 100%     6    2      4  2010       0
# 25041  90  или более, но не 100%     9    2      4  2010       0
# 25040                       60%.    12    2      4  2010       1
# 25039                  70 – 80%.    15    2      4  2010       1
# 25038                       40%.    21    2      4  2010       1
# 25037                       40%.     0    3      4  2010       0
# 25036                       50%.     3    3      4  2010       0
# 25035                  70 – 80%.     6    3      4  2010       0
# 25034                    20–30%.     9    3      4  2010       0
# 25033    10%  или менее, но не 0    12    3      4  2010       1
# 25032               Облаков нет.    15    3      4  2010       1
# 25031                       50%.    18    3      4  2010       1
# 25030                       50%.    21    3      4  2010       1
# 25029                       50%.     0    4      4  2010       0
# 25028                    20–30%.     3    4      4  2010       0
# 25027                  70 – 80%.     6    4      4  2010       0
# 25026                       50%.     9    4      4  2010       0
# 25025                  70 – 80%.    12    4      4  2010       1
# 25024  90  или более, но не 100%    15    4      4  2010       1
# 25023  90  или более, но не 100%    18    4      4  2010       1
# ...                          ...   ...  ...    ...   ...     ...
# 29     90  или более, но не 100%    21   21      4  2020       1
# 28     90  или более, но не 100%     0   22      4  2020       0
# 27     90  или более, но не 100%     3   22      4  2020       0
# 26                          60%.     6   22      4  2020       0
# 25     90  или более, но не 100%     9   22      4  2020       0
# 24                          60%.    12   22      4  2020       1
# 23                          60%.    15   22      4  2020       1
# 22                          40%.    18   22      4  2020       1
# 21                       20–30%.    21   22      4  2020       1
# 20                       20–30%.     0   23      4  2020       0
# 19                          50%.     3   23      4  2020       0
# 18                          60%.     6   23      4  2020       0
# 17                          60%.     9   23      4  2020       0
# 16                          60%.    12   23      4  2020       1
# 15                          60%.    15   23      4  2020       1
# 14                          60%.    18   23      4  2020       1
# 13                          60%.    21   23      4  2020       1
# 12                       20–30%.     0   24      4  2020       0
# 11                       20–30%.     3   24      4  2020       0
# 10                       20–30%.     6   24      4  2020       0
# 9                           50%.     9   24      4  2020       0
# 8                          100%.    12   24      4  2020       1
# 7                          100%.    15   24      4  2020       1
# 6      90  или более, но не 100%    18   24      4  2020       1
# 5                      70 – 80%.    21   24      4  2020       1
# 4      90  или более, но не 100%     0   25      4  2020       0
# 3      90  или более, но не 100%     3   25      4  2020       0
# 2                      70 – 80%.     6   25      4  2020       0
# 1                      70 – 80%.     9   25      4  2020       0
# 0                      70 – 80%.    12   25      4  2020       1
#
# [25053 rows x 8 columns]

# %%
table0.loc[(table0['N'] == 'Облаков нет.') & (table0['W1'].isnull())]
# Out:
#           T   W1             N  hour  day  month  year  status
# 25032  13.3  NaN  Облаков нет.    15    3      4  2010       1
# 24983   8.6  NaN  Облаков нет.     9   10      4  2010       0
# 24982  12.8  NaN  Облаков нет.    12   10      4  2010       1
# 24963   5.1  NaN  Облаков нет.    21   12      4  2010       1
# 24962   2.3  NaN  Облаков нет.     0   13      4  2010       0
# 24950  12.9  NaN  Облаков нет.    12   14      4  2010       1
# 24914   4.1  NaN  Облаков нет.     3   19      4  2010       0
# 24913   4.1  NaN  Облаков нет.     6   19      4  2010       0
# 24846  13.5  NaN  Облаков нет.    18   27      4  2010       1
# 24788  10.6  NaN  Облаков нет.     3    5      5  2010       0
# 24761  23.2  NaN  Облаков нет.    12    8      5  2010       1
# 24732  13.6  NaN  Облаков нет.     3   12      5  2010       0
# 24730  21.8  NaN  Облаков нет.     9   12      5  2010       0
# 24724  11.6  NaN  Облаков нет.     3   13      5  2010       0
# 24722  20.3  NaN  Облаков нет.     9   13      5  2010       0
# 24721  24.2  NaN  Облаков нет.    12   13      5  2010       1
# 24685  14.6  NaN  Облаков нет.     0   18      5  2010       0
# 24684  14.7  NaN  Облаков нет.     3   18      5  2010       0
# 24679  19.7  NaN  Облаков нет.    18   18      5  2010       1
# 24675  10.0  NaN  Облаков нет.     6   19      5  2010       0
# 24674  13.9  NaN  Облаков нет.     9   19      5  2010       0
# 24669  13.5  NaN  Облаков нет.     0   20      5  2010       0
# 24668  10.4  NaN  Облаков нет.     3   20      5  2010       0
# 24667  12.0  NaN  Облаков нет.     6   20      5  2010       0
# 24666  19.2  NaN  Облаков нет.     9   20      5  2010       0
# 24581  13.4  NaN  Облаков нет.     0   31      5  2010       0
# 24486  22.3  NaN  Облаков нет.    21   12      6  2010       1
# 24427  22.1  NaN  Облаков нет.     9   21      6  2010       0
# 24394  31.4  NaN  Облаков нет.    12   25      6  2010       1
# 24368  24.1  NaN  Облаков нет.    18   28      6  2010       1
# ...     ...  ...           ...   ...  ...    ...   ...     ...
# 1244   -7.3  NaN  Облаков нет.     0   22     11  2019       0
# 1243   -8.1  NaN  Облаков нет.     3   22     11  2019       0
# 1242   -8.6  NaN  Облаков нет.     6   22     11  2019       0
# 1241   -8.6  NaN  Облаков нет.     9   22     11  2019       0
# 1237   -5.5  NaN  Облаков нет.    21   22     11  2019       1
# 1235   -7.8  NaN  Облаков нет.     3   23     11  2019       0
# 1167   -2.2  NaN  Облаков нет.    15    1     12  2019       1
# 820    -0.3  NaN  Облаков нет.     0   14      1  2020       0
# 638    -5.0  NaN  Облаков нет.    18    5      2  2020       1
# 515     0.4  NaN  Облаков нет.     3   21      2  2020       0
# 506     0.3  NaN  Облаков нет.     6   22      2  2020       0
# 477    -1.5  NaN  Облаков нет.    21   25      2  2020       1
# 444    -3.6  NaN  Облаков нет.     0    1      3  2020       0
# 324    -5.5  NaN  Облаков нет.     0   16      3  2020       0
# 323    -6.7  NaN  Облаков нет.     3   16      3  2020       0
# 322    -9.3  NaN  Облаков нет.     6   16      3  2020       0
# 321    -4.7  NaN  Облаков нет.     9   16      3  2020       0
# 293     4.2  NaN  Облаков нет.    21   19      3  2020       1
# 275    -4.9  NaN  Облаков нет.     3   22      3  2020       0
# 274    -6.0  NaN  Облаков нет.     6   22      3  2020       0
# 273    -4.2  NaN  Облаков нет.     9   22      3  2020       0
# 261    -1.5  NaN  Облаков нет.    21   23      3  2020       1
# 260    -3.2  NaN  Облаков нет.     0   24      3  2020       0
# 259    -4.4  NaN  Облаков нет.     3   24      3  2020       0
# 258    -5.5  NaN  Облаков нет.     6   24      3  2020       0
# 140     6.8  NaN  Облаков нет.     0    8      4  2020       0
# 108    -1.0  NaN  Облаков нет.     0   12      4  2020       0
# 107    -2.0  NaN  Облаков нет.     3   12      4  2020       0
# 92     12.1  NaN  Облаков нет.     0   14      4  2020       0
# 33      5.5  NaN  Облаков нет.     9   21      4  2020       0
#
# [1105 rows x 8 columns]

# %%
#table0['W1'] = ['Облаков нет.' for n in table0.loc[(table0['N'] == 'Облаков нет.') & (table0['W1'].isnull())]['W1']]
table0.loc[(table0['N'] == 'Облаков нет.') & (table0['W1'].isnull()), 'W1'] = 'Облаков нет.'

# %%
table0
# Out:
#           T                                                 W1  \
# 25052   5.6                                                NaN
# 25051   4.2  Облака покрывали более половины неба в течение...
# 25050   3.5  Облака покрывали более половины неба в течение...
# 25049   5.6                                                NaN
# 25048  10.1                                                NaN
# 25047  10.8                                                NaN
# 25046  11.2                                                NaN
# 25045   9.3                                                NaN
# 25044   8.5                                                NaN
# 25043   4.3                                                NaN
# 25042   3.1                                                NaN
# 25041   5.5                                                NaN
# 25040  10.4                                                NaN
# 25039  13.8                                                NaN
# 25038   9.6                                                NaN
# 25037   4.2                                                NaN
# 25036   2.2                                                NaN
# 25035   1.6                                                NaN
# 25034   4.6                                                NaN
# 25033  10.1                                                NaN
# 25032  13.3                                       Облаков нет.
# 25031  12.0                                                NaN
# 25030   9.2                                                NaN
# 25029   6.5                                                NaN
# 25028   2.9                                                NaN
# 25027   0.5                                                NaN
# 25026   4.7                                                NaN
# 25025  10.2                                                NaN
# 25024  12.6                                                NaN
# 25023  11.5                                                NaN
# ...     ...                                                ...
# 29      6.3                                                NaN
# 28      5.5                                                NaN
# 27      5.2                                                NaN
# 26      4.3                                                NaN
# 25      5.4  Облака покрывали более половины неба в течение...
# 24      4.3                                    Ливень (ливни).
# 23      6.4                                    Ливень (ливни).
# 22      6.7  Облака покрывали более половины неба в течение...
# 21      4.6  Облака покрывали половину неба или менее в теч...
# 20      3.3  Облака покрывали половину неба или менее в теч...
# 19      2.1                                                NaN
# 18      1.8                                                NaN
# 17      5.5                                                NaN
# 16      8.4                                                NaN
# 15      9.8                                                NaN
# 14      9.0                                                NaN
# 13      4.3                                                NaN
# 12      1.2                                                NaN
# 11     -2.1                                                NaN
# 10     -1.0                                                NaN
# 9       4.1                                                NaN
# 8       8.1                                                NaN
# 7       6.8                                    Ливень (ливни).
# 6       6.3                                    Ливень (ливни).
# 5       5.5                                    Ливень (ливни).
# 4       5.0                                                NaN
# 3       3.7                                    Ливень (ливни).
# 2       3.4                                    Ливень (ливни).
# 1       5.2                                    Ливень (ливни).
# 0       7.7                                                NaN
#
#                                N  hour  day  month  year  status
# 25052  90  или более, но не 100%     0    1      4  2010       0
# 25051  90  или более, но не 100%     3    1      4  2010       0
# 25050  90  или более, но не 100%     6    1      4  2010       0
# 25049                  70 – 80%.     9    1      4  2010       0
# 25048  90  или более, но не 100%    12    1      4  2010       1
# 25047  90  или более, но не 100%    15    1      4  2010       1
# 25046  90  или более, но не 100%    18    1      4  2010       1
# 25045  90  или более, но не 100%    21    1      4  2010       1
# 25044  90  или более, но не 100%     0    2      4  2010       0
# 25043                  70 – 80%.     3    2      4  2010       0
# 25042  90  или более, но не 100%     6    2      4  2010       0
# 25041  90  или более, но не 100%     9    2      4  2010       0
# 25040                       60%.    12    2      4  2010       1
# 25039                  70 – 80%.    15    2      4  2010       1
# 25038                       40%.    21    2      4  2010       1
# 25037                       40%.     0    3      4  2010       0
# 25036                       50%.     3    3      4  2010       0
# 25035                  70 – 80%.     6    3      4  2010       0
# 25034                    20–30%.     9    3      4  2010       0
# 25033    10%  или менее, но не 0    12    3      4  2010       1
# 25032               Облаков нет.    15    3      4  2010       1
# 25031                       50%.    18    3      4  2010       1
# 25030                       50%.    21    3      4  2010       1
# 25029                       50%.     0    4      4  2010       0
# 25028                    20–30%.     3    4      4  2010       0
# 25027                  70 – 80%.     6    4      4  2010       0
# 25026                       50%.     9    4      4  2010       0
# 25025                  70 – 80%.    12    4      4  2010       1
# 25024  90  или более, но не 100%    15    4      4  2010       1
# 25023  90  или более, но не 100%    18    4      4  2010       1
# ...                          ...   ...  ...    ...   ...     ...
# 29     90  или более, но не 100%    21   21      4  2020       1
# 28     90  или более, но не 100%     0   22      4  2020       0
# 27     90  или более, но не 100%     3   22      4  2020       0
# 26                          60%.     6   22      4  2020       0
# 25     90  или более, но не 100%     9   22      4  2020       0
# 24                          60%.    12   22      4  2020       1
# 23                          60%.    15   22      4  2020       1
# 22                          40%.    18   22      4  2020       1
# 21                       20–30%.    21   22      4  2020       1
# 20                       20–30%.     0   23      4  2020       0
# 19                          50%.     3   23      4  2020       0
# 18                          60%.     6   23      4  2020       0
# 17                          60%.     9   23      4  2020       0
# 16                          60%.    12   23      4  2020       1
# 15                          60%.    15   23      4  2020       1
# 14                          60%.    18   23      4  2020       1
# 13                          60%.    21   23      4  2020       1
# 12                       20–30%.     0   24      4  2020       0
# 11                       20–30%.     3   24      4  2020       0
# 10                       20–30%.     6   24      4  2020       0
# 9                           50%.     9   24      4  2020       0
# 8                          100%.    12   24      4  2020       1
# 7                          100%.    15   24      4  2020       1
# 6      90  или более, но не 100%    18   24      4  2020       1
# 5                      70 – 80%.    21   24      4  2020       1
# 4      90  или более, но не 100%     0   25      4  2020       0
# 3      90  или более, но не 100%     3   25      4  2020       0
# 2                      70 – 80%.     6   25      4  2020       0
# 1                      70 – 80%.     9   25      4  2020       0
# 0                      70 – 80%.    12   25      4  2020       1
#
# [25053 rows x 8 columns]

# %%
table0['W1'] = [np.nan if n == ' ' else n for n in table0['W1']]

# %%
print(table0.isnull().sum())
print(table0.shape)
# Out:
# T             2
# W1        13565
# hour          0
# day           0
# month         0
# year          0
# status        0
# dtype: int64
# (25053, 7)

# %%
table0 = table0.dropna()

# %%
table0
# Out:
#           T                                                 W1  \
# 25051   4.2  Облака покрывали более половины неба в течение...
# 25050   3.5  Облака покрывали более половины неба в течение...
# 25032  13.3                                       Облаков нет.
# 25018   4.7                                    Ливень (ливни).
# 25017   7.5                                    Ливень (ливни).
# 25016   9.8                                    Ливень (ливни).
# 25013   4.7  Облака покрывали более половины неба в течение...
# 25012   2.7  Облака покрывали более половины неба в течение...
# 25011   0.6  Облака покрывали более половины неба в течение...
# 25006   1.8  Облака покрывали половину неба или менее в теч...
# 25005   0.4  Облака покрывали половину неба или менее в теч...
# 25004   7.9  Облака покрывали более половины неба в течение...
# 24992   3.0          Туман или ледяной туман или сильная мгла.
# 24991   2.1          Туман или ледяной туман или сильная мгла.
# 24990   8.6  Облака покрывали более половины неба в течение...
# 24985   0.8  Облака покрывали половину неба или менее в теч...
# 24984  -0.2  Облака покрывали половину неба или менее в теч...
# 24983   8.6                                       Облаков нет.
# 24982  12.8                                       Облаков нет.
# 24963   5.1                                       Облаков нет.
# 24962   2.3                                       Облаков нет.
# 24950  12.9                                       Облаков нет.
# 24948  11.6                                    Ливень (ливни).
# 24947   8.7                                    Ливень (ливни).
# 24946   4.9                                             Дождь.
# 24945   3.7                                             Дождь.
# 24944   2.7  Облака покрывали более половины неба в течение...
# 24932  11.8                                    Ливень (ливни).
# 24926  11.0                                    Ливень (ливни).
# 24925   8.4                                    Ливень (ливни).
# ...     ...                                                ...
# 58     -0.5                                    Ливень (ливни).
# 57      0.5                                    Ливень (ливни).
# 56      2.9                                    Ливень (ливни).
# 55      5.8                                    Ливень (ливни).
# 54      5.0                                    Ливень (ливни).
# 53      3.0                                    Ливень (ливни).
# 50      1.3  Дождь со снегом или другими видами твердых оса...
# 49      2.5  Дождь со снегом или другими видами твердых оса...
# 48      4.0                                    Ливень (ливни).
# 47      4.8                                    Ливень (ливни).
# 46      5.0                                    Ливень (ливни).
# 45      3.2                                    Ливень (ливни).
# 42     -0.5  Облака покрывали более половины неба в течение...
# 40      6.2  Облака покрывали более половины неба в течение...
# 39      7.2                                    Ливень (ливни).
# 38      5.9                                    Ливень (ливни).
# 37      4.1                                    Ливень (ливни).
# 33      5.5                                       Облаков нет.
# 25      5.4  Облака покрывали более половины неба в течение...
# 24      4.3                                    Ливень (ливни).
# 23      6.4                                    Ливень (ливни).
# 22      6.7  Облака покрывали более половины неба в течение...
# 21      4.6  Облака покрывали половину неба или менее в теч...
# 20      3.3  Облака покрывали половину неба или менее в теч...
# 7       6.8                                    Ливень (ливни).
# 6       6.3                                    Ливень (ливни).
# 5       5.5                                    Ливень (ливни).
# 3       3.7                                    Ливень (ливни).
# 2       3.4                                    Ливень (ливни).
# 1       5.2                                    Ливень (ливни).
#
#                                                        N  hour  day  month  \
# 25051                          90  или более, но не 100%     3    1      4
# 25050                          90  или более, но не 100%     6    1      4
# 25032                                       Облаков нет.    15    3      4
# 25018                          90  или более, но не 100%     9    5      4
# 25017                          90  или более, но не 100%    12    5      4
# 25016                                          70 – 80%.    15    5      4
# 25013                                          70 – 80%.     0    6      4
# 25012                                               60%.     3    6      4
# 25011                                          70 – 80%.     6    6      4
# 25006                                            20–30%.     3    7      4
# 25005                                               40%.     6    7      4
# 25004                                          70 – 80%.     9    7      4
# 24992  Небо не видно из-за тумана и/или других метеор...     3    9      4
# 24991  Небо не видно из-за тумана и/или других метеор...     9    9      4
# 24990                                            20–30%.    12    9      4
# 24985                                            20–30%.     3   10      4
# 24984                                            20–30%.     6   10      4
# 24983                                       Облаков нет.     9   10      4
# 24982                                       Облаков нет.    12   10      4
# 24963                                       Облаков нет.    21   12      4
# 24962                                       Облаков нет.     0   13      4
# 24950                                       Облаков нет.    12   14      4
# 24948                          90  или более, но не 100%    18   14      4
# 24947                                              100%.    21   14      4
# 24946                                               60%.     0   15      4
# 24945                                               50%.     3   15      4
# 24944                                               40%.     6   15      4
# 24932                                               50%.    21   16      4
# 24926                                              100%.    15   17      4
# 24925                                              100%.    18   17      4
# ...                                                  ...   ...  ...    ...
# 58                                                  60%.     6   18      4
# 57                             90  или более, но не 100%     9   18      4
# 56                                                 100%.    12   18      4
# 55                                             70 – 80%.    15   18      4
# 54                                             70 – 80%.    18   18      4
# 53                                                  50%.    21   18      4
# 50                                                 100%.     6   19      4
# 49                                                 100%.     9   19      4
# 48                             90  или более, но не 100%    12   19      4
# 47                             90  или более, но не 100%    15   19      4
# 46                             90  или более, но не 100%    18   19      4
# 45                                                  50%.    21   19      4
# 42                                                 100%.     6   20      4
# 40                                             70 – 80%.    12   20      4
# 39                                             70 – 80%.    15   20      4
# 38                                                  60%.    18   20      4
# 37                                                  60%.    21   20      4
# 33                                          Облаков нет.     9   21      4
# 25                             90  или более, но не 100%     9   22      4
# 24                                                  60%.    12   22      4
# 23                                                  60%.    15   22      4
# 22                                                  40%.    18   22      4
# 21                                               20–30%.    21   22      4
# 20                                               20–30%.     0   23      4
# 7                                                  100%.    15   24      4
# 6                              90  или более, но не 100%    18   24      4
# 5                                              70 – 80%.    21   24      4
# 3                              90  или более, но не 100%     3   25      4
# 2                                              70 – 80%.     6   25      4
# 1                                              70 – 80%.     9   25      4
#
#        year  status
# 25051  2010       0
# 25050  2010       0
# 25032  2010       1
# 25018  2010       0
# 25017  2010       1
# 25016  2010       1
# 25013  2010       0
# 25012  2010       0
# 25011  2010       0
# 25006  2010       0
# 25005  2010       0
# 25004  2010       0
# 24992  2010       0
# 24991  2010       0
# 24990  2010       1
# 24985  2010       0
# 24984  2010       0
# 24983  2010       0
# 24982  2010       1
# 24963  2010       1
# 24962  2010       0
# 24950  2010       1
# 24948  2010       1
# 24947  2010       1
# 24946  2010       0
# 24945  2010       0
# 24944  2010       0
# 24932  2010       1
# 24926  2010       1
# 24925  2010       1
# ...     ...     ...
# 58     2020       0
# 57     2020       0
# 56     2020       1
# 55     2020       1
# 54     2020       1
# 53     2020       1
# 50     2020       0
# 49     2020       0
# 48     2020       1
# 47     2020       1
# 46     2020       1
# 45     2020       1
# 42     2020       0
# 40     2020       1
# 39     2020       1
# 38     2020       1
# 37     2020       1
# 33     2020       0
# 25     2020       0
# 24     2020       1
# 23     2020       1
# 22     2020       1
# 21     2020       1
# 20     2020       0
# 7      2020       1
# 6      2020       1
# 5      2020       1
# 3      2020       0
# 2      2020       0
# 1      2020       0
#
# [12586 rows x 8 columns]

# %%
table_np = table0.values

# %%
table_np
# Out:
# array([[4.2,
#         'Облака покрывали более половины неба в течение всего соответствующего периода.',
#         '90  или более, но не 100%', ..., 4, 2010, 0],
#        [3.5,
#         'Облака покрывали более половины неба в течение всего соответствующего периода.',
#         '90  или более, но не 100%', ..., 4, 2010, 0],
#        [13.3, 'Облаков нет.', 'Облаков нет.', ..., 4, 2010, 1],
#        ...,
#        [3.7, 'Ливень (ливни).', '90  или более, но не 100%', ..., 4,
#         2020, 0],
#        [3.4, 'Ливень (ливни).', '70 – 80%.', ..., 4, 2020, 0],
#        [5.2, 'Ливень (ливни).', '70 – 80%.', ..., 4, 2020, 0]],
#       dtype=object)

# %%
def change_useless_info(data):
    i = 1
    pattern1 = data[0][1]
    while i < data.shape[0]:
        if data[i][1] == 'Состояние неба в общем не изменилось. ':
            data[i][1] = pattern1
        else:
            pattern1 = data[i][1]
        i += 1
    return data

# %%
change_useless_info(table_np).T[1]
# Out:
# array(['Дымка. ', 'Дымка. ',
#        'Ливневый(ые) дождь(и) слабый(ые) в срок наблюдения или за последний час. ',
#        ..., 'Ливневый(ые) дождь(и). ', 'Ливневый(ые) дождь(и). ',
#        'Ливневый(ые) дождь(и). '], dtype=object)

# %%
table_np
# Out:
# array([[4.2,
#         'Облака покрывали более половины неба в течение всего соответствующего периода.',
#         3, ..., 4, 2010, 0],
#        [3.5,
#         'Облака покрывали более половины неба в течение всего соответствующего периода.',
#         6, ..., 4, 2010, 0],
#        [4.7, 'Ливень (ливни).', 9, ..., 4, 2010, 0],
#        ...,
#        [3.7, 'Ливень (ливни).', 3, ..., 4, 2020, 0],
#        [3.4, 'Ливень (ливни).', 6, ..., 4, 2020, 0],
#        [5.2, 'Ливень (ливни).', 9, ..., 4, 2020, 0]], dtype=object)

# %%
table1['W1'].unique()
# Out:
# array(['Облака покрывали более половины неба в течение всего соответствующего периода.',
#        'Ливень (ливни).',
#        'Облака покрывали половину неба или менее в течение всего соответствующего периода.',
#        'Облака покрывали более половины неба в течение одной части соответствующего периода и половину или менее в течение другой части периода.',
#        'Туман или ледяной туман или сильная мгла.', 'Дождь.', 'Морось.',
#        'Гроза (грозы) с осадками или без них.',
#        'Дождь со снегом или другими видами твердых осадков',
#        'Снег и/или другие виды твердых осадков', 'Метель', 'Буря'],
#       dtype=object)

# %%
table['Nh'].unique()
# Out:
# array(['60%.', '50%.', '70 – 80%.', '100%.', '90  или более, но не 100%',
#        'Облаков нет.', '40%.', '20–30%.', '10%  или менее, но не 0', nan],
#       dtype=object)

# %%
table1
# Out:
#           T                                                 W1  hour  day  \
# 23067  -8.8             Снег и/или другие виды твердых осадков     3    1
# 23066  -6.7             Снег и/или другие виды твердых осадков     9    1
# 23065  -6.8             Снег и/или другие виды твердых осадков    15    1
# 23064  -6.7             Снег и/или другие виды твердых осадков    21    1
# 23063  -5.6                                    Ливень (ливни).     3    2
# 23062  -4.4                                    Ливень (ливни).     9    2
# 23061  -1.8                                    Ливень (ливни).    15    2
# 23060  -2.2                                    Ливень (ливни).    21    2
# 23059  -4.6                                    Ливень (ливни).     3    3
# 23058  -8.0             Снег и/или другие виды твердых осадков     9    3
# 23057  -8.9             Снег и/или другие виды твердых осадков    15    3
# 23056  -9.6                                    Ливень (ливни).    21    3
# 23055  -9.1                                    Ливень (ливни).     3    4
# 23054  -8.3                                    Ливень (ливни).     9    4
# 23053  -8.0             Снег и/или другие виды твердых осадков    15    4
# 23052 -13.3             Снег и/или другие виды твердых осадков    21    4
# 23051 -12.0             Снег и/или другие виды твердых осадков     3    5
# 23050 -10.8             Снег и/или другие виды твердых осадков     9    5
# 23049 -10.8             Снег и/или другие виды твердых осадков    15    5
# 23048  -8.0             Снег и/или другие виды твердых осадков    21    5
# 23047  -7.9             Снег и/или другие виды твердых осадков     3    6
# 23046  -6.3             Снег и/или другие виды твердых осадков     9    6
# 23039  -8.5             Снег и/или другие виды твердых осадков     9    8
# 23038  -5.8             Снег и/или другие виды твердых осадков    15    8
# 23037  -4.9             Снег и/или другие виды твердых осадков    21    8
# 23036  -4.0             Снег и/или другие виды твердых осадков     3    9
# 23035  -3.1             Снег и/или другие виды твердых осадков     9    9
# 23034  -1.1                                    Ливень (ливни).    15    9
# 23033  -0.6             Снег и/или другие виды твердых осадков    21    9
# 23032   0.2                                             Дождь.     3   10
# ...     ...                                                ...   ...  ...
# 706    -6.7                                    Ливень (ливни).     6   28
# 705    -6.5             Снег и/или другие виды твердых осадков     9   28
# 704    -5.4             Снег и/или другие виды твердых осадков    12   28
# 703    -4.4             Снег и/или другие виды твердых осадков    15   28
# 702    -4.3             Снег и/или другие виды твердых осадков    18   28
# 701    -3.7             Снег и/или другие виды твердых осадков    21   28
# 700    -3.0             Снег и/или другие виды твердых осадков     0   29
# 699    -2.3             Снег и/или другие виды твердых осадков     3   29
# 698    -1.3             Снег и/или другие виды твердых осадков     6   29
# 697     0.0             Снег и/или другие виды твердых осадков     9   29
# 696     1.0  Дождь со снегом или другими видами твердых оса...    12   29
# 695     0.7  Дождь со снегом или другими видами твердых оса...    15   29
# 694     0.8  Облака покрывали более половины неба в течение...    18   29
# 693     0.6  Облака покрывали более половины неба в течение...    21   29
# 692    -0.1  Облака покрывали более половины неба в течение...     0   30
# 691    -0.2             Снег и/или другие виды твердых осадков     3   30
# 690    -0.5             Снег и/или другие виды твердых осадков     6   30
# 689    -0.8             Снег и/или другие виды твердых осадков     9   30
# 688    -0.7             Снег и/или другие виды твердых осадков    12   30
# 687    -0.8             Снег и/или другие виды твердых осадков    15   30
# 686    -1.5                                    Ливень (ливни).    18   30
# 685    -1.2                                    Ливень (ливни).    21   30
# 684    -0.5             Снег и/или другие виды твердых осадков     0   31
# 683    -0.3             Снег и/или другие виды твердых осадков     3   31
# 682    -0.4             Снег и/или другие виды твердых осадков     6   31
# 681    -0.4             Снег и/или другие виды твердых осадков     9   31
# 680     0.1  Дождь со снегом или другими видами твердых оса...    12   31
# 679     0.8  Дождь со снегом или другими видами твердых оса...    15   31
# 678     0.1                                    Ливень (ливни).    18   31
# 677    -1.2             Снег и/или другие виды твердых осадков    21   31
#
#        month  year  status
# 23067      1  2011       0
# 23066      1  2011       0
# 23065      1  2011       1
# 23064      1  2011       1
# 23063      1  2011       0
# 23062      1  2011       0
# 23061      1  2011       1
# 23060      1  2011       1
# 23059      1  2011       0
# 23058      1  2011       0
# 23057      1  2011       1
# 23056      1  2011       1
# 23055      1  2011       0
# 23054      1  2011       0
# 23053      1  2011       1
# 23052      1  2011       1
# 23051      1  2011       0
# 23050      1  2011       0
# 23049      1  2011       1
# 23048      1  2011       1
# 23047      1  2011       0
# 23046      1  2011       0
# 23039      1  2011       0
# 23038      1  2011       1
# 23037      1  2011       1
# 23036      1  2011       0
# 23035      1  2011       0
# 23034      1  2011       1
# 23033      1  2011       1
# 23032      1  2011       0
# ...      ...   ...     ...
# 706        1  2020       0
# 705        1  2020       0
# 704        1  2020       1
# 703        1  2020       1
# 702        1  2020       1
# 701        1  2020       1
# 700        1  2020       0
# 699        1  2020       0
# 698        1  2020       0
# 697        1  2020       0
# 696        1  2020       1
# 695        1  2020       1
# 694        1  2020       1
# 693        1  2020       1
# 692        1  2020       0
# 691        1  2020       0
# 690        1  2020       0
# 689        1  2020       0
# 688        1  2020       1
# 687        1  2020       1
# 686        1  2020       1
# 685        1  2020       1
# 684        1  2020       0
# 683        1  2020       0
# 682        1  2020       0
# 681        1  2020       0
# 680        1  2020       1
# 679        1  2020       1
# 678        1  2020       1
# 677        1  2020       1
#
# [1563 rows x 7 columns]

# %%
table['W1'].fillna(0, inplace=True)
table_np = table.values
# Out:
# /home/dmitry/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
table1 = table0.loc[(table0['month'] == 1)]
table2 = table0.loc[(table0['month'] == 2)]
table3 = table0.loc[(table0['month'] == 3)]
table4 = table0.loc[(table0['month'] == 4)]
table5 = table0.loc[(table0['month'] == 5)]
table6 = table0.loc[(table0['month'] == 6)]
table7 = table0.loc[(table0['month'] == 7)]
table8 = table0.loc[(table0['month'] == 8)]
table9 = table0.loc[(table0['month'] == 9)]
table10 = table0.loc[(table0['month'] == 10)]
table11 = table0.loc[(table0['month'] == 11)]
table12 = table0.loc[(table0['month'] == 12)]

# %%
table_np1 = table1.values
table_np2 = table2.values
table_np3 = table3.values
table_np4 = table4.values
table_np5 = table5.values
table_np6 = table6.values
table_np7 = table7.values
table_np8 = table8.values
table_np9 = table9.values
table_np10 = table10.values
table_np11 = table11.values
table_np12 = table12.values

# %%
np.unique(table_np.T[1])
# Out:
# array(['Буря', 'Гроза (грозы) с осадками или без них.',
#        'Дождь со снегом или другими видами твердых осадков', 'Дождь.',
#        'Ливень (ливни).', 'Метель', 'Морось.',
#        'Облака покрывали более половины неба в течение всего соответствующего периода.',
#        'Облака покрывали более половины неба в течение одной части соответствующего периода и половину или менее в течение другой части периода.',
#        'Облака покрывали половину неба или менее в течение всего соответствующего периода.',
#        'Снег и/или другие виды твердых осадков',
#        'Туман или ледяной туман или сильная мгла.'], dtype=object)

# %%
def preprocessing(data):
    processing_data = data
    for i in processing_data:
        
        
        if i[1] in {'Ливень (ливни).', 'Дождь.', 'Морось.', 'Туман или ледяной туман или сильная мгла.', 'Гроза (грозы) с осадками или без них.'}:
            i[1] = 2
        elif i[1] in {'Снег и/или другие виды твердых осадков', 'Дождь со снегом или другими видами твердых осадков', 'Метель', 'Буря'}:
            i[1] = 3
        elif i[1] in {'Облака покрывали более половины неба в течение всего соответствующего периода.',
                      'Облака покрывали более половины неба в течение одной части соответствующего периода и половину или менее в течение другой части периода.'}:
            i[1] = 1
        else:
            i[1] = 0
    return processing_data
        
            
'''array(['Ливень (ливни).', nan,
       'Облака покрывали более половины неба в течение всего соответствующего периода.',
       'Дождь.', 'Снег и/или другие виды твердых осадков',
       'Облака покрывали половину неба или менее в течение всего соответствующего периода.',
       'Туман или ледяной туман или сильная мгла.',
       'Дождь со снегом или другими видами твердых осадков', 'Морось.',
       'Гроза (грозы) с осадками или без них.',
       'Облака покрывали более половины неба в течение одной части соответствующего периода и половину или менее в течение другой части периода.',
       'Метель'], dtype=object)'''
'''array(['60%.', '50%.', '70 – 80%.', '100%.', '90  или более, но не 100%',
       'Облаков нет.', '40%.', '20–30%.', '10%  или менее, но не 0', nan],
      dtype=object)'''
# Out:
# "array(['60%.', '50%.', '70 – 80%.', '100%.', '90  или более, но не 100%',\n       'Облаков нет.', '40%.', '20–30%.', '10%  или менее, но не 0', nan],\n      dtype=object)"

# %%
test = preprocessing(table_np)

# %%
print(test)
print(table_np[0:5].T[1])
# Out:
# [[4.2 1 3 ... 4 2010 0]
#  [3.5 1 6 ... 4 2010 0]
#  [4.7 2 9 ... 4 2010 0]
#  ...
#  [3.7 2 3 ... 4 2020 0]
#  [3.4 2 6 ... 4 2020 0]
#  [5.2 2 9 ... 4 2020 0]]
# [1 1 2 2 2]

# %%
test = table_np[0:5]
test
# Out:
# array([[4.2, 1, 3, 1, 4, 2010, 0],
#        [3.5, 1, 6, 1, 4, 2010, 0],
#        [4.7, 2, 9, 5, 4, 2010, 0],
#        [7.5, 2, 12, 5, 4, 2010, 1],
#        [9.8, 2, 15, 5, 4, 2010, 1]], dtype=object)

# %%
def voiting(data):
    cond_0 = 0
    cond_1 = 0
    cond_2 = 0
    cond_3 = 0
    if len(data) != 8:
        for i in data:
            if i[1] == 0:
                cond_0 += 1
            if i[1] == 1:
                cond_1 += 1
            if i[1] == 2:
                cond_2 += 1
            if i[1] == 3:
                cond_3 += 1
    else:
        return data
    res = np.copy(data[0])
    res[1] = np.argmax([cond_0, cond_1, cond_2, cond_3])
    res[0] = np.mean(data.T[0])
    return res

# %%
print(voiting(test))
# Out:
# [5.9399999999999995 2 3 1 4 2010 0]

# %%
def data_aggregate(data):
    new_data = np.array([])
    i = 0
    while i < data.shape[0]:
        _date = data[i][4]
        _status = data[i][7]
        processing = np.array([])
        processing = np.append(processing, np.copy(data[i]))
        if i+1 < data.shape[0]:
            while (data[i+1][4] == _date) and (data[i+1][7] == _status):
                processing = np.append(processing, data[i+1])
                processing = np.reshape(processing, (-1, len(data[i])))
                if i+2 < data.shape[0]:
                    i += 1
                else:
                    break
        result = voiting(processing)
        new_data = np.append(new_data, result)
        i += 1
    return np.reshape(new_data, (-1, len(data[i-1])))

# %%
arrg_data = data_aggregate(table_np)

# %%
arrg_data
# Out:
# array([[3.85, 1, 3, ..., 4, 2010, 0],
#        [4.7, 2, 9, ..., 4, 2010, 0],
#        [8.65, 2, 12, ..., 4, 2010, 1],
#        ...,
#        [6.2, 2, 15, ..., 4, 2020, 1],
#        [4.1000000000000005, 2, 3, ..., 4, 2020, 0],
#        [5.2, 2, 9, ..., 4, 2020, 0]], dtype=object)

# %% [markdown]
# $\begin{equation*}
# T =
# \begin{pmatrix}
# su\rightarrow su & su\rightarrow c  & su\rightarrow r & su\rightarrow sn\\
# c\rightarrow su & c\rightarrow c & c\rightarrow r & c\rightarrow sn\\
# r\rightarrow su & r\rightarrow c & r\rightarrow r & r\rightarrow sn\\
# sn\rightarrow su & sn\rightarrow c & sn\rightarrow r & sn\rightarrow sn
# \end{pmatrix}
# \end{equation*}$

# %%
def func_coef(data):
    #total = data.shape[0]
    rainy = 0
    sunny = 0
    snowy = 0
    cloudy = 0
    matrix = np.zeros((4, 4))
    i = 0
    while i < data.shape[0]-1:
        if data[i][1] == 2:
            rainy += 1
            matrix[2][data[i+1][1]] += 1 
        elif data[i][1] == 3:
            snowy += 1
            matrix[3][data[i+1][1]] += 1
        elif data[i][1] == 1:
            cloudy += 1
            matrix[1][data[i+1][1]] += 1
        else:
            sunny += 1
            matrix[0][data[i+1][1]] += 1
        i += 1 
    if sunny > 0:
        matrix[0] = matrix[0] / sunny
    if cloudy > 0:
        matrix[1] = matrix[1] / cloudy
    if rainy > 0:
        matrix[2] = matrix[2] / rainy
    if snowy > 0:
        matrix[3] = matrix[3] / snowy
    elif snowy == 0:
        matrix[3] = [0.25, 0.25, 0.25, 0.25]
    return matrix
    '''np.zeros((5, 5))
    j = 0
    for i in data:
        j += 1
        if j == data.shape[0]:
            break
        if i[]:
    '''

# %%
func_coef(table_np[0:5])
# Out:
# array([[0. , 0. , 0. , 0. ],
#        [0. , 0.5, 0.5, 0. ],
#        [0. , 0. , 0. , 0. ],
#        [0. , 0. , 2. , 0. ]])

# %%
matrixes = []
tables_monthes = []
for i in range(12):
    name = 'table_np'
    name += str(i+1)
    tables_monthes.append(name)

# %%
t1 = preprocessing(table_np1)
t2 = preprocessing(table_np2)
t3 = preprocessing(table_np3)
t4 = preprocessing(table_np4)
t5 = preprocessing(table_np5)
t6 = preprocessing(table_np6)
t7 = preprocessing(table_np7)
t8 = preprocessing(table_np8)
t9 = preprocessing(table_np9)
t10 = preprocessing(table_np10)
t11 = preprocessing(table_np11)
t12 = preprocessing(table_np12)

# %%
data1 = data_aggregate(t1)
data2 = data_aggregate(t2)
data3 = data_aggregate(t3)
data4 = data_aggregate(t4)
data5 = data_aggregate(t5)
data6 = data_aggregate(t6)
data7 = data_aggregate(t7)
data8 = data_aggregate(t8)
data9 = data_aggregate(t9)
data10 = data_aggregate(t10)
data11 = data_aggregate(t11)
data12 = data_aggregate(t12)

# %%
M1 = func_coef(t1)
M2 = func_coef(t2)
M3 = func_coef(t3)
M4 = func_coef(t4)
M5 = func_coef(t5)
M6 = func_coef(t6)
M7 = func_coef(t7)
M8 = func_coef(t8)
M9 = func_coef(t9)
M10 = func_coef(t10)
M11 = func_coef(t11)
M12 = func_coef(t12)

# %%
np.array([0.7, 0.3, 0, 0]) @ M4
# Out:
# array([0.43904762, 0.16609524, 0.33409524, 0.0607619 ])

# %%
m1 = func_coef(t1)
m2 = func_coef(t2)
m3 = func_coef(t3)
m4 = func_coef(t4)
m5 = func_coef(t5)
m6 = func_coef(t6)
m7 = func_coef(t7)
m8 = func_coef(t8)
m9 = func_coef(t9)
m10 = func_coef(t10)
m11 = func_coef(t11)
m12 = func_coef(t12)

# %%
np.array([0.2, 0.6, 0, 0.2, 0]) @ m1
# Out:
# array([0.47274725, 0.01025641, 0.00827839, 0.1043956 , 0.40432234])

# %%
np.sum(M12, axis=1)
# Out:
# array([1., 1., 1., 1.])

# %%
m1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-641-7b4f1e4c8b97> in <module>
# ----> 1 m1
#
# NameError: name 'm1' is not defined

# %%
m1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-399-7b4f1e4c8b97> in <module>
# ----> 1 m1
#
# NameError: name 'm1' is not defined

# %%
table_np
# Out:
# array([[4.2, 0, '90  или более, но не 100%', ..., 4, 2010, 0],
#        [3.5, 0, '90  или более, но не 100%', ..., 4, 2010, 0],
#        [13.3, 0, 'Облаков нет.', ..., 4, 2010, 1],
#        ...,
#        [3.7, 0, '90  или более, но не 100%', ..., 4, 2020, 0],
#        [3.4, 0, '70 – 80%.', ..., 4, 2020, 0],
#        [5.2, 0, '70 – 80%.', ..., 4, 2020, 0]], dtype=object)

# %%
test = preprocessing(table_np)

# %%
test
# Out:
# array([[4.2, 1, '90  или более, но не 100%', ..., 4, 2010, 0],
#        [3.5, 1, '90  или более, но не 100%', ..., 4, 2010, 0],
#        [13.3, 0, 'Облаков нет.', ..., 4, 2010, 1],
#        ...,
#        [3.7, 2, '90  или более, но не 100%', ..., 4, 2020, 0],
#        [3.4, 2, '70 – 80%.', ..., 4, 2020, 0],
#        [5.2, 2, '70 – 80%.', ..., 4, 2020, 0]], dtype=object)

# %%
d = data_aggregate(test)

# %%
d[0:5]
# Out:
# array([[3.85, 1, '90  или более, но не 100%', 3, 1, 4, 2010, 0],
#        [13.3, 0, 'Облаков нет.', 15, 3, 4, 2010, 1],
#        [4.7, 2, '90  или более, но не 100%', 9, 5, 4, 2010, 0],
#        [8.65, 2, '90  или более, но не 100%', 12, 5, 4, 2010, 1],
#        [2.6666666666666665, 1, '70 – 80%.', 0, 6, 4, 2010, 0]],
#       dtype=object)

# %%
def temp_comp(data):
    result = np.array([])
    i = 0
    while i < data.shape[0]-1:
        if data[i+1][0] - data[i][0] < -5:
            result = np.append(result, 0)
        elif (data[i+1][0] - data[i][0] >= -5) and (data[i+1][0] - data[i][0] < -2):
            result = np.append(result, 1)
        elif (data[i+1][0] - data[i][0] >= -2) and (data[i+1][0] - data[i][0] <= 2):
            result = np.append(result, 2)
        elif (data[i+1][0] - data[i][0] > 2) and (data[i+1][0] - data[i][0] <= 5):
            result = np.append(result, 3)
        else:
            result = np.append(result, 4)
        i += 1
    return result

# %%
diff1 = temp_comp(data1)
diff2 = temp_comp(data2)
diff3 = temp_comp(data3)
diff4 = temp_comp(data4)
diff5 = temp_comp(data5)
diff6 = temp_comp(data6)
diff7 = temp_comp(data7)
diff8 = temp_comp(data8)
diff9 = temp_comp(data9)
diff10 = temp_comp(data10)
diff11 = temp_comp(data11)
diff12 = temp_comp(data12)

# %%
T1 = temp_matrix(diff1)
T2 = temp_matrix(diff2)
T3 = temp_matrix(diff3)
T4 = temp_matrix(diff4)
T5 = temp_matrix(diff5)
T6 = temp_matrix(diff6)
T7 = temp_matrix(diff7)
T8 = temp_matrix(diff8)
T9 = temp_matrix(diff9)
T10 = temp_matrix(diff10)
T11 = temp_matrix(diff11)
T12 = temp_matrix(diff12)

# %%
T1
# Out:
# array([[0.15      , 0.1       , 0.35      , 0.2       , 0.2       ],
#        [0.04819277, 0.10843373, 0.53012048, 0.19277108, 0.12048193],
#        [0.02531646, 0.17721519, 0.67721519, 0.10126582, 0.01898734],
#        [0.02985075, 0.19402985, 0.59701493, 0.14925373, 0.02985075],
#        [0.125     , 0.125     , 0.45833333, 0.20833333, 0.08333333]])

# %%
diff
# Out:
# array([4., 0., 3., ..., 3., 1., 2.])

# %%
def temp_matrix(data):
    l5 = 0
    l2 = 0
    b = 0
    m2 = 0
    m5 = 0
    matrix = np.zeros((5, 5))
    i = 0
    while i < data.shape[0]-1:
        if data[i] == 0:
            l5 += 1
            matrix[0][int(data[i+1])] += 1
        elif data[i] == 1:
            l2 += 1
            matrix[1][int(data[i+1])] += 1
        elif data[i] == 2:
            b += 1
            matrix[2][int(data[i+1])] += 1
        elif data[i] == 3:
            m2 += 1
            matrix[3][int(data[i+1])] += 1
        else:
            m5 += 1
            matrix[4][int(data[i+1])] += 1
        i += 1
    if l5 > 0:
        matrix[0] = matrix[0] / l5
    elif l5 == 0:
        matrix[0] = [0.333, 0.333, 0.333, 0.333]
    if l2 > 0:
        matrix[1] = matrix[1] / l2
    elif l2 == 0:
        matrix[1] = [0.333, 0.333, 0.333, 0.333]
    if b > 0:
        matrix[2] = matrix[2] / b
    elif b == 0:
        matrix[2] = [0.333, 0.333, 0.333, 0.333]
    if m2 > 0:
        matrix[3] = matrix[3] / m2
    elif b == 0:
        matrix[3] = [0.333, 0.333, 0.333, 0.333]
    if m5 > 0:
        matrix[4] = matrix[4] / m5
    elif m5 == 0:
        matrix[4] = [0.333, 0.333, 0.333, 0.333]
    return matrix

# %%
temp_matrix(diff)
# Out:
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# array([[0.03141361, 0.07853403, 0.34554974, 0.20942408, 0.33507853],
#        [0.04381443, 0.09536082, 0.46134021, 0.24613402, 0.15335052],
#        [0.04719894, 0.17159241, 0.60388178, 0.13762682, 0.03970004],
#        [0.11798561, 0.28776978, 0.44460432, 0.10935252, 0.04028777],
#        [0.39095745, 0.22074468, 0.26595745, 0.09574468, 0.02659574]])
